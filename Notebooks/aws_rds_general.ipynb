# %% [markdown]
# # AWS RDS - General
# This notebook connect to the AWS RDS object (using Boto3) to show important features about the PG Host which are not accessible using SQL

# %%
import boto3

def get_aws_credentials():
    aws_access_key_id = "AKIAVGLKJXRNSJ4GJIOK"
    aws_secret_access_key = "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"
    region_name = "eu-central-1"

    return aws_access_key_id, aws_secret_access_key, region_name

def list_rds_instances(access_key_id, secret_access_key, region_name):
    try:
        # Create a session using AWS credentials
        session = boto3.Session(
            aws_access_key_id=access_key_id,
            aws_secret_access_key=secret_access_key,
            region_name=region_name
        )

        # Create an RDS client
        rds_client = session.client('rds')

        # Retrieve the RDS instances
        response = rds_client.describe_db_instances()

        # Get the RDS instance information
        rds_instances = response['DBInstances']
        return rds_instances

    except Exception as e:
        print("An error occurred:", str(e))

    return []

# Usage example
access_key_id, secret_access_key, region_name = get_aws_credentials()
rds_instances = list_rds_instances(access_key_id, secret_access_key, region_name)

if len(rds_instances) > 0:
    print("RDS Instances:")
    for instance in rds_instances:
        instance_id = instance['DBInstanceIdentifier']
        instance_class = instance['DBInstanceClass']
        endpoint = instance['Endpoint']['Address']
        print("Instance ID:", instance_id)
        print("Instance Class:", instance_class)
        print("Endpoint:", endpoint)
        print("---")
else:
    print("No RDS instances found.")
# Out:
# RDS Instances:
# Instance ID: database-2
# Instance Class: db.m6g.large
# Endpoint: database-2.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# Instance ID: metis-prod-v2
# Instance Class: db.m6g.large
# Endpoint: metis-prod-v2.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# Instance ID: mysql-for-test
# Instance Class: db.t3.micro
# Endpoint: mysql-for-test.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---

# %% [markdown]
# # Get Details of a specific RDS
# Use the instance ID to get more details about the RDS

# %%
import boto3

def create_aws_session(access_key_id, secret_access_key, region_name):
    try:
        # Create a session using AWS credentials
        session = boto3.Session(
            aws_access_key_id=access_key_id,
            aws_secret_access_key=secret_access_key,
            region_name=region_name
        )
        return session
    except Exception as e:
        print("An error occurred while creating the AWS session:", str(e))
        return None

def list_rds_instances(session):
    try:
        if session is None:
            print("AWS session is not valid.")
            return []

        # Create an RDS client using the session
        rds_client = session.client('rds')

        # Retrieve the RDS instances
        response = rds_client.describe_db_instances()

        # Get the RDS instance information
        rds_instances = response['DBInstances']
        return rds_instances

    except Exception as e:
        print("An error occurred while listing RDS instances:", str(e))
        return []

# Usage example

access_key_id = "AKIAVGLKJXRNSJ4GJIOK"
secret_access_key = "vrElF6ZrHbdjwJwPjMoqXW34qdQT08ISQY6fTz7q"
region_name = "eu-central-1"

session = create_aws_session(access_key_id, secret_access_key, region_name)
rds_instances = list_rds_instances(session)

if len(rds_instances) > 0:
    print("RDS Instances:")
    for instance in rds_instances:
        instance_id = instance['DBInstanceIdentifier']
        instance_class = instance['DBInstanceClass']
        endpoint = instance['Endpoint']['Address']
        print("Instance ID:", instance_id)
        print("Instance Class:", instance_class)
        print("Endpoint:", endpoint)
        print("---")
else:
    print("No RDS instances found.")
# Out:
# RDS Instances:
# Instance ID: database-2
# Instance Class: db.m6g.large
# Endpoint: database-2.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# Instance ID: metis-prod-v2
# Instance Class: db.m6g.large
# Endpoint: metis-prod-v2.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# Instance ID: mysql-for-test
# Instance Class: db.t3.micro
# Endpoint: mysql-for-test.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---

# %% [markdown]
# Step 3

# %%
import boto3

def create_aws_session(access_key_id, secret_access_key, region_name):
    try:
        # Create a session using AWS credentials
        session = boto3.Session(
            aws_access_key_id=access_key_id,
            aws_secret_access_key=secret_access_key,
            region_name=region_name
        )
        return session
    except Exception as e:
        print("An error occurred while creating the AWS session:", str(e))
        return None

def list_rds_instances(session):
    try:
        if session is None:
            print("AWS session is not valid.")
            return []

        # Create an RDS client using the session
        rds_client = session.client('rds')

        # Retrieve the RDS instances
        response = rds_client.describe_db_instances()

        # Get the RDS instance information
        rds_instances = response['DBInstances']
        return rds_instances

    except Exception as e:
        print("An error occurred while listing RDS instances:", str(e))
        return []

def rds_details_old(rds_name, session):
    try:
        if session is None:
            print("AWS session is not valid.")
            return

        # Create an RDS client using the session
        rds_client = session.client('rds')

        # Retrieve the RDS instance details
        response = rds_client.describe_db_instances(DBInstanceIdentifier=rds_name)

        if 'DBInstances' in response:
            rds_instance = response['DBInstances'][0]
            instance_name = rds_instance['DBInstanceIdentifier']
            instance_type = rds_instance['DBInstanceClass']

            print("RDS Instance Name:", instance_name)
            print("RDS Instance Type:", instance_type)

            print("RDS Instance Details:")
            for key, value in rds_instance.items():
                print(key + ":", value)
            print("---")
        else:
            print("RDS instance not found:", rds_name)

    except Exception as e:
        print("An error occurred while retrieving RDS instance details:", str(e))


import pandas as pd

def rds_details(rds_name, session):
    try:
        if session is None:
            print("AWS session is not valid.")
            return None

        # Create an RDS client using the session
        rds_client = session.client('rds')

        # Retrieve the RDS instance details
        response = rds_client.describe_db_instances(DBInstanceIdentifier=rds_name)

        if 'DBInstances' in response:
            rds_instance = response['DBInstances'][0]

            # Convert the instance details to a pandas DataFrame
            df = pd.DataFrame.from_dict(rds_instance, orient='index', columns=['Value'])
            df.index.name = 'Property'

            return df
        else:
            print("RDS instance not found:", rds_name)

    except Exception as e:
        print("An error occurred while retrieving RDS instance details:", str(e))

    return None

# Usage example
access_key_id = "AKIAVGLKJXRNSJ4GJIOK"
secret_access_key = "vrElF6ZrHbdjwJwPjMoqXW34qdQT08ISQY6fTz7q"
region_name = "eu-central-1"

session = create_aws_session(access_key_id, secret_access_key, region_name)
rds_instances = list_rds_instances(session)

if len(rds_instances) > 0:
    print("RDS Instances:")
    for instance in rds_instances:
        instance_id = instance['DBInstanceIdentifier']
        instance_class = instance['DBInstanceClass']
        endpoint = instance['Endpoint']['Address']
        print("Instance ID:", instance_id)
        print("Instance Class:", instance_class)
        print("Endpoint:", endpoint)
        print("---")

    rds_name = "database-2"
    rds_details(rds_name, session)
else:
    print("No RDS instances found.")

rds_name = "database-2"
df = rds_details(rds_name, session)

if df is not None:
    print("RDS Instance Details:")
    print(df)

    # Save DataFrame to a file (e.g., CSV)
    df.to_csv("rds_instance_details.csv", index=True)

    # Print DataFrame
    print("---")
    print("DataFrame saved to 'rds_instance_details.csv'.")
else:
    print("No RDS instance details available.")
# Out:
# RDS Instances:
# Instance ID: database-2
# Instance Class: db.m6g.large
# Endpoint: database-2.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# Instance ID: metis-prod-v2
# Instance Class: db.m6g.large
# Endpoint: metis-prod-v2.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# Instance ID: mysql-for-test
# Instance Class: db.t3.micro
# Endpoint: mysql-for-test.cofhrj7zmyn4.eu-central-1.rds.amazonaws.com
# ---
# RDS Instance Details:
#                                                                                 Value
# Property
# DBInstanceIdentifier                                                       database-2
# DBInstanceClass                                                          db.m6g.large
# Engine                                                                       postgres
# DBInstanceStatus                                                            available
# MasterUsername                                                               postgres
# Endpoint                            {'Address': 'database-2.cofhrj7zmyn4.eu-centra...
# AllocatedStorage                                                                  200
# InstanceCreateTime                                   2022-03-24 17:25:30.255000+00:00
# PreferredBackupWindow                                                     21:43-22:13
# BackupRetentionPeriod                                                               3
# DBSecurityGroups                                                                   []
# VpcSecurityGroups                   [{'VpcSecurityGroupId': 'sg-0c434c09330b44937'...
# DBParameterGroups                   [{'DBParameterGroupName': 'pg-dev-parameter-gr...
# AvailabilityZone                                                        eu-central-1b
# DBSubnetGroup                       {'DBSubnetGroupName': 'default-vpc-093c6339566...
# PreferredMaintenanceWindow                                        fri:23:19-fri:23:49
# PendingModifiedValues                                                              {}
# LatestRestorableTime                                        2023-06-07 21:04:38+00:00
# MultiAZ                                                                         False
# EngineVersion                                                                    13.7
# AutoMinorVersionUpgrade                                                          True
# ReadReplicaDBInstanceIdentifiers                                                   []
# LicenseModel                                                       postgresql-license
# Iops                                                                             3000
# OptionGroupMemberships              [{'OptionGroupName': 'default:postgres-13', 'S...
# PubliclyAccessible                                                               True
# StorageType                                                                       gp3
# DbInstancePort                                                                      0
# StorageEncrypted                                                                 True
# KmsKeyId                            arn:aws:kms:eu-central-1:357242092635:key/ff5e...
# DbiResourceId                                           db-QKTCUINSKWGYV3J4BJRAGPE2E4
# CACertificateIdentifier                                                   rds-ca-2019
# DomainMemberships                                                                  []
# CopyTagsToSnapshot                                                               True
# MonitoringInterval                                                                 60
# EnhancedMonitoringResourceArn       arn:aws:logs:eu-central-1:357242092635:log-gro...
# MonitoringRoleArn                   arn:aws:iam::357242092635:role/rds-monitoring-...
# DBInstanceArn                       arn:aws:rds:eu-central-1:357242092635:db:datab...
# IAMDatabaseAuthenticationEnabled                                                False
# PerformanceInsightsEnabled                                                       True
# PerformanceInsightsKMSKeyId         arn:aws:kms:eu-central-1:357242092635:key/ff5e...
# PerformanceInsightsRetentionPeriod                                                  7
# EnabledCloudwatchLogsExports                                    [postgresql, upgrade]
# DeletionProtection                                                               True
# AssociatedRoles                                                                    []
# MaxAllocatedStorage                                                              1000
# TagList                             [{'Key': 'copilot-application', 'Value': 'meti...
# CustomerOwnedIpEnabled                                                          False
# ActivityStreamStatus                                                          stopped
# BackupTarget                                                                   region
# NetworkType                                                                      IPV4
# StorageThroughput                                                                 125
# ---
# DataFrame saved to 'rds_instance_details.csv'.
