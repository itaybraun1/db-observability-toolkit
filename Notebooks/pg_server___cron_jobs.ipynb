# %% [markdown]
# # pg_server___cron_jobs
# Provides information about cron jobs running in the DB.
#
# Cells:
# - Configure: Connect to a specfic DB
# - Current size of each table: in KB, dead rows, bloat, data size, all indexes size,
#
#
# PreReq:
# - ```pip install cron-descriptor```

# %%
import sys
print(sys.path)

from cron_descriptor import get_description, ExpressionDescriptor
# Out:
# ['/Users/itaybraun/Documents/GitHub/db-observability-toolkit/Notebooks/Notebooks_Drafts', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python310.zip', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload', '', '/Users/itaybraun/Library/Python/3.10/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages']

# %%
import sqlalchemy
import pandas as pd
import configparser
import matplotlib.pyplot as plt 
from IPython.display import HTML


# Read from the Config file
config = configparser.ConfigParser() 
# As long as the notebook in the "Notebooks_Drafts" folder, use r'../../ipynb.cfg'
config.read_file(open(r'../../ipynb.cfg'))

con_str = config.get('con_str', 'PG_AIRBASES') 
engine = sqlalchemy.create_engine(con_str)

try:
    connection = engine.connect()
    print ("Opened Connection")
except (Exception, sqlalchemy.exc.SQLAlchemyError) as error:
    print("Error while connecting to PostgreSQL database:", error)
# Out:
# Opened Connection

# %% [markdown]
# ## Configuration
# View the configurations related to the cron jobs in the current DB

# %%
qry_cron_configuration = """
-- Cron Jobs
SELECT name, setting, short_desc, extra_desc, source, min_val, max_val
FROM pg_settings 
WHERE name like '%%cron%%' 
"""
df = pd.read_sql_query(qry_cron_configuration, connection)
df
# Out:
#                           name    setting  \
# 0           cron.database_name   airbases
# 1   cron.enable_superuser_jobs         on
# 2                    cron.host  localhost
# 3        cron.log_min_messages    warning
# 4                 cron.log_run         on
# 5           cron.log_statement         on
# 6        cron.max_running_jobs          1
# 7  cron.use_background_workers         on
#
#                                           short_desc  \
# 0        Database in which pg_cron metadata is kept.
# 1            Allow jobs to be scheduled as superuser
# 2                   Hostname to connect to postgres.
# 3        log_min_messages for the launcher bgworker.
# 4   Log all jobs runs into the job_run_details table
# 5        Log all cron statements prior to execution.
# 6  Maximum number of jobs that can run concurrently.
# 7  Use background workers instead of client sessi...
#
#                                           extra_desc              source  \
# 0                                               None  configuration file
# 1                                               None             default
# 2  This setting has no effect when background wor...             default
# 3                                               None  configuration file
# 4                                               None  configuration file
# 5                                               None  configuration file
# 6                                               None  configuration file
# 7                                               None  configuration file
#
#   min_val max_val
# 0    None    None
# 1    None    None
# 2    None    None
# 3    None    None
# 4    None    None
# 5    None    None
# 6       0       7
# 7    None    None

# %% [markdown]
# ## Number of jobs and size of the history table

# %%
qry_jobs_tables_stats = """ 
SELECT 
	min(j.count_jobs) as count_jobs, 
	count(jobid) as count_history_rows, 
  min(start_time) as oldest_job_history,
  now() -  min(start_time) as oldest_job_history_str,
  max(start_time) as newest_job_history
FROM cron.job_run_details AS rd
cross join ( SELECT count(*) as count_jobs
from cron.job) as j """ 
df = pd.read_sql_query(qry_jobs_tables_stats, connection)
df
# Out:
#    count_jobs  count_history_rows               oldest_job_history  \
# 0           6              123523 2023-05-21 15:30:00.068394+00:00
#
#     oldest_job_history_str               newest_job_history
# 0 107 days 05:35:16.302263 2023-09-05 21:05:02.371539+00:00

# %% [markdown]
# ## Analyze the size of the job_run_details
# If the value is higher than 10,000 (feel free to select any other value) then you should run a daily job to delete data older than 7 days (or any other history length)
#
# TODO: write here the command:

# %%
# Find the value of the 'count_history_rows' column
value = df['count_history_rows'].iloc[0]

# Check if the value is higher than 10000 and display it in red if true
if value > 10000:
    message = f"<font color='pink'>The value of count_history_rows ({value}) is higher than 10000</font>"
else:
    message = f"The value of count_history_rows ({value}) is within the allowed limit."

# Display the message with HTML formatting
display(HTML(message))
# Out:
# <font color='pink'>The value of count_history_rows (123523) is higher than 10000</font>

# %% [markdown]
# ## The Details of the Job
# For each job show its:
# - jobid and name
# - is active

# %%
qry_jobs_details = """ 

-- Jobs' details
SELECT 
	jobid,  
  schedule, 
  command, 
  length(command),
  nodename, 
  nodeport, 
  database, 
  username, 
  active
  jobname
FROM cron.job; """ 
print(get_description("* 2 3 * *"))

df = pd.read_sql_query(qry_jobs_details, connection)
df["schedule_text"] = df["schedule"].apply(get_description)
df
# Out:
# Every minute, between 02:00 AM and 02:59 AM, on day 3 of the month
#    jobid      schedule                                            command  \
# 0      1  */10 * * * *  select *\nfrom (select * from postgres_air.boa...
# 1      3   */1 * * * *  \n        -- Your SQL query goes here\n       ...
# 2      4   */1 * * * *  \n        INSERT INTO metis.pg_stat_tables_act...
# 3      5     0 1 * * *   \n    SELECT delete_old_data_periodically()\n
# 4      6   */1 * * * *  INSERT INTO metis.queries (query_id, query_tex...
# 5      7   */5 * * * *  \n    INSERT INTO metis.query_stats_snapshots ...
#
#    length   nodename  nodeport  database  username  jobname     schedule_text
# 0     170  localhost      5432  airbases  postgres     True  Every 10 minutes
# 1     738  localhost      5432  airbases  postgres     True      Every minute
# 2     854  localhost      5432  airbases  postgres     True      Every minute
# 3      46  localhost      5432  airbases  postgres     True       At 01:00 AM
# 4     462  localhost      5432  airbases  postgres     True      Every minute
# 5     516  localhost      5432  airbases  postgres     True   Every 5 minutes

# %% [markdown]
# ## Job Execution Statistics
# Some statistics about the jobs run in the last 7 days (Configurable):
# - Number of times the job run
# - How many times it finished succesfully or with a failure.
# - Avg duration.
# - First time and last time it run in the monitored duration.

# %%
qry_job_history_stats = """ 
--
SELECT 
	j.jobid, 
  j.jobname,
	count(runid) as count_job_runs, 
  SUM (case rd.status
  	WHEN 'succeeded' then 1 ELSE 0 END) AS count_success, 
  SUM (case rd.status
  	WHEN 'failed' then 1 ELSE 0 END) AS count_failure, 
  --count(runid) / SUM ((case rd.status WHEN 'failed' then 1 ELSE 0 END)::numeric) as success_pct,  
  min(start_time) AS first_run, 
  max(start_time) AS last_run,
 	SUM( 
    	(EXTRACT(EPOCH FROM end_time - start_time) * 1000)::bigint 
    ) AS total_job_duration_ms, 
  SUM( 
    	(EXTRACT(EPOCH FROM end_time - start_time) * 1000)::bigint 
    )  / 
  SUM (case rd.status WHEN 'succeeded' then 1 ELSE 0 END) AS avg_duration_succesful_runs
FROM 
	cron.job_run_details AS rd
JOIN 
	cron.job AS j 
  	ON rd.jobid = j.jobid
WHERE j.active = true
GROUP BY 
	j.jobid, 
  j.jobname

"""
df = pd.read_sql_query(qry_job_history_stats, connection)
df
# Out:
#    jobid                              jobname  count_job_runs  count_success  \
# 0      1                 pmc data reliability            8890           8889
# 1      3                          my_cron_job           39374          39362
# 2      4    pg_stat_tables_activity_snapshots           34904          34893
# 3      5          pg_monitor__delete_old_data              24             24
# 4      6           pg_stat_statements_queries           33538          33515
# 5      7  pg_stat_statements_queries_measures            6695           6693
#
#    count_failure                        first_run  \
# 0              1 2023-05-21 15:30:00.068394+00:00
# 1             12 2023-08-09 12:23:00.036840+00:00
# 2             11 2023-08-12 14:53:00.010841+00:00
# 3              0 2023-08-13 01:00:00.062161+00:00
# 4             23 2023-08-13 13:39:00.006730+00:00
# 5              2 2023-08-13 14:45:02.118176+00:00
#
#                           last_run  total_job_duration_ms  \
# 0 2023-09-05 20:30:00.118706+00:00              3280967.0
# 1 2023-09-05 20:36:00.094432+00:00              9682712.0
# 2 2023-09-05 20:36:00.085173+00:00             11839064.0
# 3 2023-09-05 01:00:01.120887+00:00                71629.0
# 4 2023-09-05 20:36:00.025178+00:00              2304282.0
# 5 2023-09-05 20:35:00.097408+00:00              1467343.0
#
#    avg_duration_succesful_runs
# 0                   369.104174
# 1                   245.991362
# 2                   339.296249
# 3                  2984.541667
# 4                    68.753752
# 5                   219.235470

# %% [markdown]
# ## Run Details of a specific Job

# %%
qry_job_run_details = """ 
-- Last 100 runs
SELECT * 
FROM cron.job_run_details 
WHERE jobid = 3
ORDER BY start_time desc
LIMIT 100;   """ 

df = pd.read_sql_query(qry_job_run_details, connection)
df
# Out:
#     jobid   runid  job_pid  database  username  \
# 0       3    5131      NaN  airbases  postgres
# 1       3   63903      NaN  airbases  postgres
# 2       3   63906      NaN  airbases  postgres
# 3       3   65295      NaN  airbases  postgres
# 4       3   64315      NaN  airbases  postgres
# ..    ...     ...      ...       ...       ...
# 95      3  123153   3545.0  airbases  postgres
# 96      3  123150   3436.0  airbases  postgres
# 97      3  123147   3328.0  airbases  postgres
# 98      3  123143   3213.0  airbases  postgres
# 99      3  123139   3104.0  airbases  postgres
#
#                                               command     status  \
# 0   \n        -- Your SQL query goes here\n       ...     failed
# 1   \n        -- Your SQL query goes here\n       ...     failed
# 2   \n        -- Your SQL query goes here\n       ...     failed
# 3   \n        -- Your SQL query goes here\n       ...     failed
# 4   \n        -- Your SQL query goes here\n       ...     failed
# ..                                                ...        ...
# 95  \n        -- Your SQL query goes here\n       ...  succeeded
# 96  \n        -- Your SQL query goes here\n       ...  succeeded
# 97  \n        -- Your SQL query goes here\n       ...  succeeded
# 98  \n        -- Your SQL query goes here\n       ...  succeeded
# 99  \n        -- Your SQL query goes here\n       ...  succeeded
#
#                                        return_message  \
# 0   could not start background process; more detai...
# 1   could not start background process; more detai...
# 2   could not start background process; more detai...
# 3   could not start background process; more detai...
# 4   could not start background process; more detai...
# ..                                                ...
# 95                                         INSERT 0 1
# 96                                         INSERT 0 1
# 97                                         INSERT 0 1
# 98                                         INSERT 0 1
# 99                                         INSERT 0 1
#
#                          start_time                         end_time
# 0                               NaT                              NaT
# 1                               NaT                              NaT
# 2                               NaT                              NaT
# 3                               NaT                              NaT
# 4                               NaT                              NaT
# ..                              ...                              ...
# 95 2023-09-05 19:13:00.088169+00:00 2023-09-05 19:13:00.093132+00:00
# 96 2023-09-05 19:12:00.093097+00:00 2023-09-05 19:12:00.098530+00:00
# 97 2023-09-05 19:11:00.087964+00:00 2023-09-05 19:11:00.093244+00:00
# 98 2023-09-05 19:10:00.268865+00:00 2023-09-05 19:10:00.273953+00:00
# 99 2023-09-05 19:09:00.091831+00:00 2023-09-05 19:09:00.096815+00:00
#
# [100 rows x 10 columns]

# %% [markdown]
# ## Testing Mini series
# Aug 21 - test failed. Can't show it all in one object.

# %%
import pandas as pd
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# Create empty DataFrame
data = {
    'product_name': [],
    'orderdate': [],
    'order_amount': []
}

# List of products
products = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']

# Generate 10 random dates for each product
for product in products:
    for _ in range(10):
        random_date = datetime(2023, random.randint(1, 12), random.randint(1, 28))
        data['product_name'].append(product)
        data['orderdate'].append(random_date)
        data['order_amount'].append(random.randint(100, 1000))

# Create DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
# print(df)
# Create subplots for each product
fig = plt.figure(figsize=(10, 8))
gs = GridSpec(5, 1, figure=fig)

for i, product in enumerate(products):
    ax = fig.add_subplot(gs[i, 0])
    product_data = df[df['product_name'] == product]
    ax.bar(product_data['orderdate'], product_data['order_amount'])
    ax.set_title(product)
    ax.set_xlabel('Order Date')
    ax.set_ylabel('Order Amount')

plt.tight_layout()
plt.show()
